# %% [markdown]
# ### Object Detection Video with TensorFlow

# %% [markdown]
# ##### What is Object Detection?

# %% [markdown]
# Object detection is a computer vision technique that works to identify and locate objects within an image or video. Specifically, object detection draws bounding boxes around these detected objects, which allow us to locate where said objects are in (or how they move through) a given scene.

# %% [markdown]
# Image recognition assigns a label to an image. A picture of a dog receives the label “dog”. A picture of two dogs, still receives the label “dog”. Object detection, on the other hand, draws a box around each dog and labels the box “dog”. The model predicts where each object is and what label should be applied. In that way, object detection provides more information about an image than recognition.

# %% [markdown]
# To start performing **Video Object Detection**, you must download the **RetinaNet, YOLOv3 or TinyYOLOv3** object detection model via the links below:
#
# **RetinaNet** (Size = 145 mb, high performance and accuracy, with longer detection time)<br>
# **YOLOv3** (Size = 237 mb, moderate performance and accuracy, with a moderate detection time)<br>
# **TinyYOLOv3** (Size = 34 mb, optimized for speed and moderate performance, with fast detection time)<br>
#
# We can **download** the model file by using below link.
#
# [YOLO.H5](https://github.com/OlafenwaMoses/ImageAI/releases/download/1.0/yolo.h5)<br>
# [YOLO.tiny.H5](https://github.com/OlafenwaMoses/ImageAI/releases/tag/1.0/)<br>
# [RetinaNet](https://github.com/OlafenwaMoses/ImageAI/releases/download/1.0/resnet50_coco_best_v2.0.1.h5)

# %% [markdown]
# These models supported by ImageAI can detect 80 different types of objects. They are:<br>
#
#       person, bicycle, car, motorcycle, airplane, bus, train, truck, boat, traffic light, fire hydrant, stop_sign,
#       parking meter,   bench,   bird,   cat,   dog,   horse,   sheep,   cow,   elephant,   bear,   zebra,
#       giraffe,   backpack,   umbrella,   handbag,   tie,   suitcase,   frisbee,   skis,   snowboard,
#       sports ball,   kite,   baseball bat,   baseball glove,   skateboard,   surfboard,   tennis racket,
#       bottle,   wine glass,   cup,   fork,   knife,   spoon,   bowl,   banana,   apple,   sandwich,   orange,
#       broccoli,   carrot,   hot dog,   pizza,   donot,   cake,   chair,   couch,   potted plant,   bed,
#       dining table,   toilet,   tv,   laptop,   mouse,   remote,   keyboard,   cell phone,   microwave,
#       oven,   toaster,   sink,   refrigerator,   book,   clock,   vase,   scissors,   teddy bear,   hair dryer,
#       toothbrush.

# %% [markdown]
# ###### For processing the video detection the following packaes need to be installed on your pc
# TensorFlow/Numpy/SciPy/OpenCV/Pillow/Matplotlib/h5py/keras/ImageAI

# %%
# User defined function for printing output
def forFrame(frame_number, output_array, output_count, detected_copy):
    print("FOR FRAME " , frame_number)
#    print("Output for each object : ", output_array)
    print("Output count for unique objects : ", output_count)
    print("------------END OF A FRAME --------------")

# %%
from imageai.Detection import VideoObjectDetection
import os

execution_path = os.getcwd()

detector = VideoObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath( os.path.join(execution_path , "yolo.h5"))
detector.loadModel()

video_path = detector.detectObjectsFromVideo(input_file_path=os.path.join(execution_path, "E:\\my data\\DATA SCIENCE\\DEEP LERNING\\Input\\Videos\\traffic-mini.mp4"),
                                output_file_path=os.path.join(execution_path, "E:\\my data\\DATA SCIENCE\\DEEP LERNING\\Output\\video\\traffic-mini1.mp4")
                                , frames_per_second=20,
                                             per_frame_function = forFrame,
                                             minimum_percentage_probability=30,
                                             log_progress=True,
                                             return_detected_frame=True)

print(video_path)
# Out:
# Processing Frame :  1
# FOR FRAME  1
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 17, 'bicycle': 1, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  2
# FOR FRAME  2
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 2, 'car': 18, 'bicycle': 1, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  3
# FOR FRAME  3
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 18, 'bicycle': 1, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  4
# FOR FRAME  4
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 17, 'bicycle': 1, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  5
# FOR FRAME  5
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 17, 'bicycle': 2, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  6
# FOR FRAME  6
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 17, 'bicycle': 1, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  7
# FOR FRAME  7
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 15, 'bicycle': 2, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  8
# FOR FRAME  8
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 17, 'bicycle': 1, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  9
# FOR FRAME  9
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 16, 'bicycle': 1, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  10
# FOR FRAME  10
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 16, 'bicycle': 1, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  11
# FOR FRAME  11
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 16, 'bicycle': 1, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  12
# FOR FRAME  12
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 16, 'bicycle': 1, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  13
# FOR FRAME  13
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 15, 'bicycle': 1, 'person': 13}
# ------------END OF A FRAME --------------
# Processing Frame :  14
# FOR FRAME  14
# Output count for unique objects :  {'bus': 4, 'motorcycle': 3, 'car': 14, 'bicycle': 1, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  15
# FOR FRAME  15
# Output count for unique objects :  {'bus': 4, 'motorcycle': 3, 'car': 15, 'bicycle': 1, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  16
# FOR FRAME  16
# Output count for unique objects :  {'bus': 3, 'motorcycle': 3, 'car': 17, 'bicycle': 1, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  17
# FOR FRAME  17
# Output count for unique objects :  {'bus': 3, 'motorcycle': 3, 'car': 16, 'bicycle': 1, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  18
# FOR FRAME  18
# Output count for unique objects :  {'bus': 3, 'motorcycle': 3, 'car': 16, 'bicycle': 1, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  19
# FOR FRAME  19
# Output count for unique objects :  {'bus': 3, 'motorcycle': 3, 'car': 17, 'bicycle': 1, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  20
# FOR FRAME  20
# Output count for unique objects :  {'bus': 3, 'motorcycle': 3, 'car': 15, 'bicycle': 1, 'person': 14}
# ------------END OF A FRAME --------------
# Processing Frame :  21
# FOR FRAME  21
# Output count for unique objects :  {'bus': 3, 'motorcycle': 3, 'car': 15, 'bicycle': 1, 'person': 14}
# ------------END OF A FRAME --------------
# Processing Frame :  22
# FOR FRAME  22
# Output count for unique objects :  {'bus': 3, 'motorcycle': 3, 'car': 15, 'bicycle': 1, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  23
# FOR FRAME  23
# Output count for unique objects :  {'bus': 3, 'motorcycle': 3, 'car': 13, 'bicycle': 1, 'person': 14}
# ------------END OF A FRAME --------------
# Processing Frame :  24
# FOR FRAME  24
# Output count for unique objects :  {'bus': 3, 'motorcycle': 3, 'car': 14, 'bicycle': 1, 'person': 14}
# ------------END OF A FRAME --------------
# Processing Frame :  25
# FOR FRAME  25
# Output count for unique objects :  {'bus': 3, 'motorcycle': 3, 'car': 14, 'bicycle': 1, 'person': 14}
# ------------END OF A FRAME --------------
# Processing Frame :  26
# FOR FRAME  26
# Output count for unique objects :  {'bus': 3, 'motorcycle': 3, 'car': 11, 'bicycle': 1, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  27
# FOR FRAME  27
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 10, 'bicycle': 1, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  28
# FOR FRAME  28
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 2, 'car': 12, 'bicycle': 1, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  29
# FOR FRAME  29
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 12, 'bicycle': 1, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  30
# FOR FRAME  30
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 12, 'bicycle': 1, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  31
# FOR FRAME  31
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 13, 'bicycle': 1, 'person': 13}
# ------------END OF A FRAME --------------
# Processing Frame :  32
# FOR FRAME  32
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 13, 'bicycle': 1, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  33
# FOR FRAME  33
# Output count for unique objects :  {'bus': 4, 'motorcycle': 2, 'car': 13, 'bicycle': 1, 'person': 13}
# ------------END OF A FRAME --------------
# Processing Frame :  34
# FOR FRAME  34
# Output count for unique objects :  {'bus': 4, 'motorcycle': 2, 'car': 13, 'bicycle': 1, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  35
# FOR FRAME  35
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 14, 'bicycle': 1, 'person': 13}
# ------------END OF A FRAME --------------
# Processing Frame :  36
# FOR FRAME  36
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 14, 'bicycle': 1, 'person': 13}
# ------------END OF A FRAME --------------
# Processing Frame :  37
# FOR FRAME  37
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 12, 'bicycle': 1, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  38
# FOR FRAME  38
# Output count for unique objects :  {'bus': 3, 'car': 14, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  39
# FOR FRAME  39
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 12, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  40
# FOR FRAME  40
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 12, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  41
# FOR FRAME  41
# Output count for unique objects :  {'bus': 3, 'car': 12, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  42
# FOR FRAME  42
# Output count for unique objects :  {'bus': 3, 'car': 12, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  43
# FOR FRAME  43
# Output count for unique objects :  {'bus': 3, 'car': 14, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  44
# FOR FRAME  44
# Output count for unique objects :  {'bus': 3, 'car': 16, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  45
# FOR FRAME  45
# Output count for unique objects :  {'bus': 3, 'car': 15, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  46
# FOR FRAME  46
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 12, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  47
# FOR FRAME  47
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 12, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  48
# FOR FRAME  48
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 13, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  49
# FOR FRAME  49
# Output count for unique objects :  {'bus': 3, 'car': 12, 'bicycle': 3, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  50
# FOR FRAME  50
# Output count for unique objects :  {'bus': 3, 'car': 11, 'bicycle': 3, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  51
# FOR FRAME  51
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 11, 'bicycle': 3, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  52
# FOR FRAME  52
# Output count for unique objects :  {'bus': 3, 'car': 10, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  53
# FOR FRAME  53
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 2, 'car': 10, 'bicycle': 2, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  54
# FOR FRAME  54
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 2, 'car': 9, 'bicycle': 2, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  55
# FOR FRAME  55
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 1, 'car': 11, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  56
# FOR FRAME  56
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 1, 'car': 13, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  57
# FOR FRAME  57
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 1, 'car': 12, 'bicycle': 2, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  58
# FOR FRAME  58
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 2, 'car': 12, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  59
# FOR FRAME  59
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 1, 'car': 13, 'bicycle': 2, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  60
# FOR FRAME  60
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 1, 'car': 13, 'bicycle': 3, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  61
# FOR FRAME  61
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 11, 'bicycle': 2, 'person': 12}
# ------------END OF A FRAME --------------
# Processing Frame :  62
# FOR FRAME  62
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 13, 'bicycle': 2, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  63
# FOR FRAME  63
# Output count for unique objects :  {'bus': 3, 'car': 11, 'bicycle': 2, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  64
# FOR FRAME  64
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'car': 12, 'bicycle': 2, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  65
# FOR FRAME  65
# Output count for unique objects :  {'bus': 4, 'car': 11, 'bicycle': 2, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  66
# FOR FRAME  66
# Output count for unique objects :  {'bus': 4, 'car': 11, 'bicycle': 2, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  67
# FOR FRAME  67
# Output count for unique objects :  {'bus': 5, 'car': 12, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  68
# FOR FRAME  68
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 13, 'bicycle': 2, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  69
# FOR FRAME  69
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 14, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  70
# FOR FRAME  70
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 15, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  71
# FOR FRAME  71
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 15, 'bicycle': 3, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  72
# FOR FRAME  72
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 15, 'bicycle': 3, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  73
# FOR FRAME  73
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 14, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  74
# FOR FRAME  74
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 14, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  75
# FOR FRAME  75
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 16, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  76
# FOR FRAME  76
# Output count for unique objects :  {'bus': 3, 'car': 15, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  77
# FOR FRAME  77
# Output count for unique objects :  {'bus': 4, 'car': 16, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  78
# FOR FRAME  78
# Output count for unique objects :  {'bus': 4, 'car': 15, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  79
# FOR FRAME  79
# Output count for unique objects :  {'bus': 4, 'car': 17, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  80
# FOR FRAME  80
# Output count for unique objects :  {'bus': 4, 'car': 15, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  81
# FOR FRAME  81
# Output count for unique objects :  {'bus': 4, 'car': 15, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  82
# FOR FRAME  82
# Output count for unique objects :  {'bus': 4, 'car': 13, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  83
# FOR FRAME  83
# Output count for unique objects :  {'bus': 4, 'car': 12, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  84
# FOR FRAME  84
# Output count for unique objects :  {'bus': 4, 'car': 11, 'bicycle': 2, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  85
# FOR FRAME  85
# Output count for unique objects :  {'bus': 3, 'car': 11, 'bicycle': 2, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  86
# FOR FRAME  86
# Output count for unique objects :  {'bus': 4, 'car': 9, 'bicycle': 2, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  87
# FOR FRAME  87
# Output count for unique objects :  {'bus': 4, 'car': 10, 'bicycle': 2, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  88
# FOR FRAME  88
# Output count for unique objects :  {'bus': 4, 'car': 7, 'bicycle': 2, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  89
# FOR FRAME  89
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 6, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  90
# FOR FRAME  90
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 6, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  91
# FOR FRAME  91
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 6, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  92
# FOR FRAME  92
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 8, 'bicycle': 2, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  93
# FOR FRAME  93
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 8, 'bicycle': 1, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  94
# FOR FRAME  94
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 9, 'bicycle': 1, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  95
# FOR FRAME  95
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 10, 'bicycle': 1, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  96
# FOR FRAME  96
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 12, 'bicycle': 2, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  97
# FOR FRAME  97
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 12, 'bicycle': 2, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  98
# FOR FRAME  98
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 11, 'bicycle': 2, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  99
# FOR FRAME  99
# Output count for unique objects :  {'bus': 3, 'car': 8, 'bicycle': 2, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  100
# FOR FRAME  100
# Output count for unique objects :  {'bus': 3, 'car': 10, 'bicycle': 3, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  101
# FOR FRAME  101
# Output count for unique objects :  {'bus': 3, 'car': 9, 'bicycle': 4, 'person': 11}
# ------------END OF A FRAME --------------
# Processing Frame :  102
# FOR FRAME  102
# Output count for unique objects :  {'bus': 2, 'car': 12, 'bicycle': 3, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  103
# FOR FRAME  103
# Output count for unique objects :  {'bus': 2, 'car': 11, 'bicycle': 3, 'person': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  104
# FOR FRAME  104
# Output count for unique objects :  {'bus': 2, 'car': 9, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  105
# FOR FRAME  105
# Output count for unique objects :  {'bus': 2, 'car': 12, 'bicycle': 2, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  106
# FOR FRAME  106
# Output count for unique objects :  {'bus': 2, 'car': 12, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  107
# FOR FRAME  107
# Output count for unique objects :  {'bus': 2, 'car': 12, 'bicycle': 3, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  108
# FOR FRAME  108
# Output count for unique objects :  {'bus': 3, 'car': 13, 'bicycle': 3, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  109
# FOR FRAME  109
# Output count for unique objects :  {'bus': 3, 'car': 13, 'bicycle': 3, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  110
# FOR FRAME  110
# Output count for unique objects :  {'bus': 3, 'car': 11, 'bicycle': 3, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  111
# FOR FRAME  111
# Output count for unique objects :  {'bus': 3, 'car': 11, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  112
# FOR FRAME  112
# Output count for unique objects :  {'bus': 3, 'car': 12, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  113
# FOR FRAME  113
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 11, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  114
# FOR FRAME  114
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 10, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  115
# FOR FRAME  115
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 11, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  116
# FOR FRAME  116
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 11, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  117
# FOR FRAME  117
# Output count for unique objects :  {'bus': 3, 'motorcycle': 3, 'car': 12, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  118
# FOR FRAME  118
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 12, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  119
# FOR FRAME  119
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 13, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  120
# FOR FRAME  120
# Output count for unique objects :  {'bus': 4, 'motorcycle': 2, 'car': 15, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  121
# FOR FRAME  121
# Output count for unique objects :  {'bus': 4, 'motorcycle': 2, 'car': 15, 'bicycle': 1, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  122
# FOR FRAME  122
# Output count for unique objects :  {'bus': 4, 'motorcycle': 2, 'car': 14, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  123
# FOR FRAME  123
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 12, 'bicycle': 1, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  124
# FOR FRAME  124
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 12, 'bicycle': 1, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  125
# FOR FRAME  125
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 13, 'bicycle': 1, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  126
# FOR FRAME  126
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 11, 'bicycle': 1, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  127
# FOR FRAME  127
# Output count for unique objects :  {'bus': 3, 'motorcycle': 2, 'car': 11, 'bicycle': 1, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  128
# FOR FRAME  128
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 13, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  129
# FOR FRAME  129
# Output count for unique objects :  {'bus': 3, 'car': 13, 'bicycle': 4, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  130
# FOR FRAME  130
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 11, 'bicycle': 2, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  131
# FOR FRAME  131
# Output count for unique objects :  {'bus': 4, 'car': 14, 'bicycle': 3, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  132
# FOR FRAME  132
# Output count for unique objects :  {'bus': 4, 'car': 14, 'bicycle': 3, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  133
# FOR FRAME  133
# Output count for unique objects :  {'bus': 4, 'car': 14, 'bicycle': 3, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  134
# FOR FRAME  134
# Output count for unique objects :  {'bus': 3, 'car': 13, 'bicycle': 3, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  135
# FOR FRAME  135
# Output count for unique objects :  {'bus': 3, 'car': 12, 'bicycle': 3, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  136
# FOR FRAME  136
# Output count for unique objects :  {'bus': 4, 'car': 11, 'bicycle': 4, 'person': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  137
# FOR FRAME  137
# Output count for unique objects :  {'bus': 4, 'car': 11, 'bicycle': 4, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  138
# FOR FRAME  138
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 12, 'bicycle': 4, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  139
# FOR FRAME  139
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 12, 'bicycle': 4, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  140
# FOR FRAME  140
# Output count for unique objects :  {'bus': 4, 'car': 11, 'bicycle': 3, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  141
# FOR FRAME  141
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 13, 'bicycle': 3, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  142
# FOR FRAME  142
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 2, 'car': 15, 'bicycle': 3, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  143
# FOR FRAME  143
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 2, 'car': 13, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  144
# FOR FRAME  144
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 1, 'car': 14, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  145
# FOR FRAME  145
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 1, 'car': 13, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  146
# FOR FRAME  146
# Output count for unique objects :  {'bus': 4, 'car': 14, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  147
# FOR FRAME  147
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 1, 'car': 13, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  148
# FOR FRAME  148
# Output count for unique objects :  {'truck': 2, 'bus': 4, 'car': 13, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  149
# FOR FRAME  149
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 2, 'car': 13, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  150
# FOR FRAME  150
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 2, 'car': 14, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  151
# FOR FRAME  151
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 2, 'car': 14, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  152
# FOR FRAME  152
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 2, 'car': 15, 'bicycle': 2, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  153
# FOR FRAME  153
# Output count for unique objects :  {'truck': 2, 'bus': 3, 'motorcycle': 2, 'car': 12, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  154
# FOR FRAME  154
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 3, 'car': 15, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  155
# FOR FRAME  155
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 2, 'car': 15, 'bicycle': 2, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  156
# FOR FRAME  156
# Output count for unique objects :  {'truck': 2, 'bus': 3, 'motorcycle': 3, 'car': 13, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  157
# FOR FRAME  157
# Output count for unique objects :  {'truck': 2, 'bus': 3, 'motorcycle': 3, 'car': 14, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  158
# FOR FRAME  158
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 2, 'car': 14, 'bicycle': 2, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  159
# FOR FRAME  159
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 2, 'car': 13, 'bicycle': 2, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  160
# FOR FRAME  160
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 2, 'car': 13, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  161
# FOR FRAME  161
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 3, 'car': 13, 'bicycle': 2, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  162
# FOR FRAME  162
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 3, 'car': 12, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  163
# FOR FRAME  163
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 3, 'car': 12, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  164
# FOR FRAME  164
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 4, 'car': 13, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  165
# FOR FRAME  165
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 3, 'car': 15, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  166
# FOR FRAME  166
# Output count for unique objects :  {'truck': 1, 'bus': 5, 'motorcycle': 3, 'car': 15, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  167
# FOR FRAME  167
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 4, 'car': 14, 'bicycle': 1, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  168
# FOR FRAME  168
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 3, 'car': 14, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  169
# FOR FRAME  169
# Output count for unique objects :  {'truck': 2, 'bus': 4, 'motorcycle': 3, 'car': 15, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  170
# FOR FRAME  170
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 2, 'car': 15, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  171
# FOR FRAME  171
# Output count for unique objects :  {'truck': 2, 'bus': 4, 'motorcycle': 2, 'car': 14, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  172
# FOR FRAME  172
# Output count for unique objects :  {'truck': 2, 'bus': 4, 'motorcycle': 2, 'car': 16, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  173
# FOR FRAME  173
# Output count for unique objects :  {'truck': 2, 'bus': 4, 'motorcycle': 2, 'car': 14, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  174
# FOR FRAME  174
# Output count for unique objects :  {'truck': 2, 'bus': 4, 'motorcycle': 2, 'car': 14, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  175
# FOR FRAME  175
# Output count for unique objects :  {'truck': 2, 'bus': 4, 'motorcycle': 2, 'car': 14, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  176
# FOR FRAME  176
# Output count for unique objects :  {'truck': 2, 'bus': 4, 'motorcycle': 2, 'car': 15, 'bicycle': 2, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  177
# FOR FRAME  177
# Output count for unique objects :  {'truck': 2, 'bus': 4, 'motorcycle': 4, 'car': 15, 'bicycle': 1, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  178
# FOR FRAME  178
# Output count for unique objects :  {'truck': 2, 'bus': 4, 'motorcycle': 4, 'car': 14, 'bicycle': 1, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  179
# FOR FRAME  179
# Output count for unique objects :  {'truck': 2, 'bus': 4, 'motorcycle': 5, 'car': 15, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# E:\my data\DATA SCIENCE\DEEP LERNING\Output\video\traffic-mini1.mp4.avi
